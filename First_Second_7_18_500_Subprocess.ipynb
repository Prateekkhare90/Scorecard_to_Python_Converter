# %%
import sys
from IPython import get_ipython

def Scorecard_to_python(p):
    from IPython.core.interactiveshell import InteractiveShell
    InteractiveShell.ast_node_interactivity = "all"

    def skip_first_line(seq, n):
        for i,item in enumerate(seq):
            if i >= n:
                yield item

    import csv

    f = open(p)
    csv_f = csv.reader(f)

    Add_line = []
    for row in skip_first_line(csv_f, 2):
    #    print(row)
        row1 = ','.join(row)
        Add_line.append(row1)

    # print(Add_line)

#     for p in Add_line:
#         print(p)

    def getmystring(s):
        list1=s.split("<")
        list3=s.split("=")
        if len(list1) == 3:
            list2=[l for l in list1]
            res=list2[1].split("=")[1]
        elif len(list1) == 2:
            list2=[l for l in list1]
            res=list2[0]
        elif len(list3) == 2:
            list4=[l for l in list3]
            res=list4[0]
        return res

    results1 = []
    def SAS_Scrd_to_Py():
        for i in Add_line:
            list1 = i.split(',')
            list2 = list1[3:]
#             print(list2)
            for j in list2:
                if list2.count(' _MISSING_') == 0:
                    results1.append('elif '+list2[0]+' :'+"DF['Score']="+list2[-1])
                elif list2.count(' _MISSING_') == 1:
                    results1.append('elif '+list2[0]+' :'+"DF['Score']="+list2[-1])
                    results1.append('elif '+"DF['"+getmystring(str(list2[0])).strip()+"']"+'=='+"'NaN'"+' :'+"DF['Score']="+list2[2])
        return results1
    SAS_Scrd_to_Py()
    print(results1)
    
    Var_list = []
    def Variable_list():
        for i in Add_line:
            list1 = i.split(',')
            list2 = list1[1]
            Var_list.append(list2)
        return Var_list

    Var_list_NOdups = []
    for d in Variable_list():
            if d not in Var_list_NOdups:
                Var_list_NOdups.append(d)
#     print(Var_list_NOdups)

    results2 = []
    for i in results1:
           if i not in results2:
            results2.append(i)
    print(results2)

    results3 = []
    def SAS_Scrd_to_Py_Mid():
        for i in results2:
            list3 = i.split(' ')
#             print(list3)
            if len(list3) == 5 and list3[2] == "<":
                list3[1]=list3[1].replace("(", "")
                results3.append(['if '+"DF['"+list3[1]+"']"+list3[2]+list3[3]+list3[4]])
            elif len(list3) == 5 and list3[2] == "<=":
                results3.append([list3[0]+' '+"DF['"+list3[3]+"']"+'>='+list3[1]+list3[4]])
            elif len(list3) == 7:
                results3.append([list3[0]+' '+list3[1]+list3[2]+"DF['"+list3[3]+"']"+list3[4]+list3[5]+list3[6]])
            elif len(list3) != 5 and len(list3) != 7:
                results3.append(list3) 
        return results3
    SAS_Scrd_to_Py_Mid()
    print(results3)   
    
    result3_1 =[]
    def SAS_Scrd_to_Py_Mid1():
        for i in results3:
            row = ', '.join(i)
            row1=row.replace(",", "")
            row2 = row1.split(',')
            result3_1.append(row2)
        return result3_1
    SAS_Scrd_to_Py_Mid1()
    
    result4=[]
    for item in result3_1:
        temp=[]
        for item1 in item:
            strg = item1
            for x in Var_list_NOdups:
                if x in strg:
                    newscore = "Score" +"_"+x
                    d=strg.replace("Score", newscore)
                    temp.append(d)
            result4.append(temp)
#     print(result4)
    
    result5 = []
    for item in result4:
        row = ', '.join(item)
        row1=row.replace(",", "")
        result5.append(row1)    
    print(result5)
    
#     for p in result5:
# #         print(p)
        
    Line_indent1 = "    "    
    Line_indent = "\n        "
    Mergewords2 = []
    for p in result5:
        q=p.find(":")
        r = Line_indent1+p[0:q+1]+Line_indent+p[q+1:]
        Mergewords2.append(r)
    Mergewords2.insert(0, "import pandas as pd")
    Mergewords2.insert(1, "def myfunc(DF):")
    #Mergewords2.insert(2, "    DF=pd.read_csv('Test_data.csv')")
#     Mergewords2.insert(0, "def if_elif_statements(DF):")
    Mergewords2.insert(len(Mergewords2), "    return DF" )
    print(Mergewords2)
    
    log = open("Py_elif48.py", "w")
    for g in Mergewords2:
        print(g, file = log) 

def Scorecard_to_python2(q):
    import pandas as pd
    from IPython.display import display
    import numpy as np 
    from Py_elif48 import myfunc
        
    DF=pd.read_csv(q)
 
    def SAStoPy_exe(DF):
        #if __name__ == "__main__":
         #   main()
        DF=myfunc(DF)
        return DF

    DF2 = DF.apply (lambda row: SAStoPy_exe(row),axis=1)
    display(DF2)

    DF2['Score_total'] = DF2[DF2.columns[-4:]].sum(axis=1)
    display(DF2)
    DF2.to_csv('Out_DF50.csv')


filename1 = ""
filename2 = ""

if len(sys.argv)==3:
    filename1 = str(sys.argv[1])
    filename2 = str(sys.argv[2])
    Scorecard_to_python(filename1)
    Scorecard_to_python2(filename2)
else:
    print("2 file must be provided")

# %%
# !jupyter nbconvert --to script First_Second_7_18_500_Subprocess.ipynb
# Out:
# [NbConvertApp] Converting notebook First_Second_7_18_500_Subprocess.ipynb to script
# [NbConvertApp] Writing 5296 bytes to First_Second_7_18_500_Subprocess.py

# %%
# !python First_Second_7_18_500_Subprocess.py SASEM_Output.csv Test_data.csv
# Out:
# ["elif MoSold < 796 :DF['Score']=30", "elif MoSold < 796 :DF['Score']=30", "elif 796 <= MoSold < 1079 :DF['Score']=38", "elif DF['MoSold']=='NaN' :DF['Score']=38", "elif 796 <= MoSold < 1079 :DF['Score']=38", "elif DF['MoSold']=='NaN' :DF['Score']=38", "elif 796 <= MoSold < 1079 :DF['Score']=38", "elif DF['MoSold']=='NaN' :DF['Score']=38", "elif 1079 <= MoSold < 1567 :DF['Score']=41", "elif 1079 <= MoSold < 1567 :DF['Score']=41", "elif 1567 <= MoSold < 1830 :DF['Score']=43", "elif 1567 <= MoSold < 1830 :DF['Score']=43", "elif 1830 <= MoSold :DF['Score']=45", "elif 1830 <= MoSold :DF['Score']=45", "elif GrLivArea < 1373 :DF['Score']=147", "elif DF['GrLivArea']=='NaN' :DF['Score']=147", "elif GrLivArea < 1373 :DF['Score']=147", "elif DF['GrLivArea']=='NaN' :DF['Score']=147", "elif GrLivArea < 1373 :DF['Score']=147", "elif DF['GrLivArea']=='NaN' :DF['Score']=147", "elif 1373 <= GrLivArea < 1540 :DF['Score']=65", "elif 1373 <= GrLivArea < 1540 :DF['Score']=65", "elif 1540 <= GrLivArea < 1944 :DF['Score']=40", "elif 1540 <= GrLivArea < 1944 :DF['Score']=40", "elif 1944 <= GrLivArea < 2464 :DF['Score']=3", "elif 1944 <= GrLivArea < 2464 :DF['Score']=3", "elif 2464 <= GrLivArea :DF['Score']=-29", "elif 2464 <= GrLivArea :DF['Score']=-29", "elif LotArea < 6000 :DF['Score']=117", "elif LotArea < 6000 :DF['Score']=117", "elif 6000 <= LotArea < 10512 :DF['Score']=71", "elif DF['LotArea']=='NaN' :DF['Score']=71", "elif 6000 <= LotArea < 10512 :DF['Score']=71", "elif DF['LotArea']=='NaN' :DF['Score']=71", "elif 6000 <= LotArea < 10512 :DF['Score']=71", "elif DF['LotArea']=='NaN' :DF['Score']=71", "elif 10512 <= LotArea < 12198 :DF['Score']=49", "elif 10512 <= LotArea < 12198 :DF['Score']=49", "elif 12198 <= LotArea < 16900 :DF['Score']=18", "elif 12198 <= LotArea < 16900 :DF['Score']=18", "elif 16900 <= LotArea :DF['Score']=-40", "elif 16900 <= LotArea :DF['Score']=-40", "elif WoodDeckSF < 100 :DF['Score']=41", "elif DF['WoodDeckSF']=='NaN' :DF['Score']=41", "elif WoodDeckSF < 100 :DF['Score']=41", "elif DF['WoodDeckSF']=='NaN' :DF['Score']=41", "elif WoodDeckSF < 100 :DF['Score']=41", "elif DF['WoodDeckSF']=='NaN' :DF['Score']=41", "elif 100 <= WoodDeckSF < 130 :DF['Score']=43", "elif 100 <= WoodDeckSF < 130 :DF['Score']=43", "elif 130 <= WoodDeckSF < 256 :DF['Score']=41", "elif 130 <= WoodDeckSF < 256 :DF['Score']=41", "elif 256 <= WoodDeckSF < 319 :DF['Score']=37", "elif 256 <= WoodDeckSF < 319 :DF['Score']=37", "elif 319 <= WoodDeckSF :DF['Score']=35", "elif 319 <= WoodDeckSF :DF['Score']=35"]
# ["elif MoSold < 796 :DF['Score']=30", "elif 796 <= MoSold < 1079 :DF['Score']=38", "elif DF['MoSold']=='NaN' :DF['Score']=38", "elif 1079 <= MoSold < 1567 :DF['Score']=41", "elif 1567 <= MoSold < 1830 :DF['Score']=43", "elif 1830 <= MoSold :DF['Score']=45", "elif GrLivArea < 1373 :DF['Score']=147", "elif DF['GrLivArea']=='NaN' :DF['Score']=147", "elif 1373 <= GrLivArea < 1540 :DF['Score']=65", "elif 1540 <= GrLivArea < 1944 :DF['Score']=40", "elif 1944 <= GrLivArea < 2464 :DF['Score']=3", "elif 2464 <= GrLivArea :DF['Score']=-29", "elif LotArea < 6000 :DF['Score']=117", "elif 6000 <= LotArea < 10512 :DF['Score']=71", "elif DF['LotArea']=='NaN' :DF['Score']=71", "elif 10512 <= LotArea < 12198 :DF['Score']=49", "elif 12198 <= LotArea < 16900 :DF['Score']=18", "elif 16900 <= LotArea :DF['Score']=-40", "elif WoodDeckSF < 100 :DF['Score']=41", "elif DF['WoodDeckSF']=='NaN' :DF['Score']=41", "elif 100 <= WoodDeckSF < 130 :DF['Score']=43", "elif 130 <= WoodDeckSF < 256 :DF['Score']=41", "elif 256 <= WoodDeckSF < 319 :DF['Score']=37", "elif 319 <= WoodDeckSF :DF['Score']=35"]
# [["if DF['MoSold']<796:DF['Score']=30"], ["elif 796<=DF['MoSold']<1079:DF['Score']=38"], ['elif', "DF['MoSold']=='NaN'", ":DF['Score']=38"], ["elif 1079<=DF['MoSold']<1567:DF['Score']=41"], ["elif 1567<=DF['MoSold']<1830:DF['Score']=43"], ["elif DF['MoSold']>=1830:DF['Score']=45"], ["if DF['GrLivArea']<1373:DF['Score']=147"], ['elif', "DF['GrLivArea']=='NaN'", ":DF['Score']=147"], ["elif 1373<=DF['GrLivArea']<1540:DF['Score']=65"], ["elif 1540<=DF['GrLivArea']<1944:DF['Score']=40"], ["elif 1944<=DF['GrLivArea']<2464:DF['Score']=3"], ["elif DF['GrLivArea']>=2464:DF['Score']=-29"], ["if DF['LotArea']<6000:DF['Score']=117"], ["elif 6000<=DF['LotArea']<10512:DF['Score']=71"], ['elif', "DF['LotArea']=='NaN'", ":DF['Score']=71"], ["elif 10512<=DF['LotArea']<12198:DF['Score']=49"], ["elif 12198<=DF['LotArea']<16900:DF['Score']=18"], ["elif DF['LotArea']>=16900:DF['Score']=-40"], ["if DF['WoodDeckSF']<100:DF['Score']=41"], ['elif', "DF['WoodDeckSF']=='NaN'", ":DF['Score']=41"], ["elif 100<=DF['WoodDeckSF']<130:DF['Score']=43"], ["elif 130<=DF['WoodDeckSF']<256:DF['Score']=41"], ["elif 256<=DF['WoodDeckSF']<319:DF['Score']=37"], ["elif DF['WoodDeckSF']>=319:DF['Score']=35"]]
# ["if DF['MoSold']<796:DF['Score_MoSold']=30", "elif 796<=DF['MoSold']<1079:DF['Score_MoSold']=38", "elif DF['MoSold']=='NaN' :DF['Score_MoSold']=38", "elif 1079<=DF['MoSold']<1567:DF['Score_MoSold']=41", "elif 1567<=DF['MoSold']<1830:DF['Score_MoSold']=43", "elif DF['MoSold']>=1830:DF['Score_MoSold']=45", "if DF['GrLivArea']<1373:DF['Score_GrLivArea']=147", "elif DF['GrLivArea']=='NaN' :DF['Score_GrLivArea']=147", "elif 1373<=DF['GrLivArea']<1540:DF['Score_GrLivArea']=65", "elif 1540<=DF['GrLivArea']<1944:DF['Score_GrLivArea']=40", "elif 1944<=DF['GrLivArea']<2464:DF['Score_GrLivArea']=3", "elif DF['GrLivArea']>=2464:DF['Score_GrLivArea']=-29", "if DF['LotArea']<6000:DF['Score_LotArea']=117", "elif 6000<=DF['LotArea']<10512:DF['Score_LotArea']=71", "elif DF['LotArea']=='NaN' :DF['Score_LotArea']=71", "elif 10512<=DF['LotArea']<12198:DF['Score_LotArea']=49", "elif 12198<=DF['LotArea']<16900:DF['Score_LotArea']=18", "elif DF['LotArea']>=16900:DF['Score_LotArea']=-40", "if DF['WoodDeckSF']<100:DF['Score_WoodDeckSF']=41", "elif DF['WoodDeckSF']=='NaN' :DF['Score_WoodDeckSF']=41", "elif 100<=DF['WoodDeckSF']<130:DF['Score_WoodDeckSF']=43", "elif 130<=DF['WoodDeckSF']<256:DF['Score_WoodDeckSF']=41", "elif 256<=DF['WoodDeckSF']<319:DF['Score_WoodDeckSF']=37", "elif DF['WoodDeckSF']>=319:DF['Score_WoodDeckSF']=35"]
# ['import pandas as pd', 'def myfunc(DF):', "    if DF['MoSold']<796:\n        DF['Score_MoSold']=30", "    elif 796<=DF['MoSold']<1079:\n        DF['Score_MoSold']=38", "    elif DF['MoSold']=='NaN' :\n        DF['Score_MoSold']=38", "    elif 1079<=DF['MoSold']<1567:\n        DF['Score_MoSold']=41", "    elif 1567<=DF['MoSold']<1830:\n        DF['Score_MoSold']=43", "    elif DF['MoSold']>=1830:\n        DF['Score_MoSold']=45", "    if DF['GrLivArea']<1373:\n        DF['Score_GrLivArea']=147", "    elif DF['GrLivArea']=='NaN' :\n        DF['Score_GrLivArea']=147", "    elif 1373<=DF['GrLivArea']<1540:\n        DF['Score_GrLivArea']=65", "    elif 1540<=DF['GrLivArea']<1944:\n        DF['Score_GrLivArea']=40", "    elif 1944<=DF['GrLivArea']<2464:\n        DF['Score_GrLivArea']=3", "    elif DF['GrLivArea']>=2464:\n        DF['Score_GrLivArea']=-29", "    if DF['LotArea']<6000:\n        DF['Score_LotArea']=117", "    elif 6000<=DF['LotArea']<10512:\n        DF['Score_LotArea']=71", "    elif DF['LotArea']=='NaN' :\n        DF['Score_LotArea']=71", "    elif 10512<=DF['LotArea']<12198:\n        DF['Score_LotArea']=49", "    elif 12198<=DF['LotArea']<16900:\n        DF['Score_LotArea']=18", "    elif DF['LotArea']>=16900:\n        DF['Score_LotArea']=-40", "    if DF['WoodDeckSF']<100:\n        DF['Score_WoodDeckSF']=41", "    elif DF['WoodDeckSF']=='NaN' :\n        DF['Score_WoodDeckSF']=41", "    elif 100<=DF['WoodDeckSF']<130:\n        DF['Score_WoodDeckSF']=43", "    elif 130<=DF['WoodDeckSF']<256:\n        DF['Score_WoodDeckSF']=41", "    elif 256<=DF['WoodDeckSF']<319:\n        DF['Score_WoodDeckSF']=37", "    elif DF['WoodDeckSF']>=319:\n        DF['Score_WoodDeckSF']=35", '    return DF']
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# 18      19          20       RL         66.0    13695   Pave   NaN      Reg
# 19      20          20       RL         70.0     7560   Pave   NaN      Reg
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# 21      22          45       RM         57.0     7449   Pave  Grvl      Reg
# 22      23          20       RL         75.0     9742   Pave   NaN      Reg
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 24      25          20       RL          NaN     8246   Pave   NaN      IR1
# 25      26          20       RL        110.0    14230   Pave   NaN      Reg
# 26      27          20       RL         60.0     7200   Pave   NaN      Reg
# 27      28          20       RL         98.0    11478   Pave   NaN      Reg
# 28      29          20       RL         47.0    16321   Pave   NaN      IR1
# 29      30          30       RM         60.0     6324   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1430  1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1432  1433          30       RL         60.0    10800   Pave  Grvl      Reg
# 1433  1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1434  1435          20       RL         80.0    17400   Pave   NaN      Reg
# 1435  1436          20       RL         80.0     8400   Pave   NaN      Reg
# 1436  1437          20       RL         60.0     9000   Pave   NaN      Reg
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1438  1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1439  1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities        ...        MiscVal MoSold YrSold SaleType  \
# 0            Lvl    AllPub        ...              0      2   2008       WD
# 1            Lvl    AllPub        ...              0      5   2007       WD
# 2            Lvl    AllPub        ...              0      9   2008       WD
# 3            Lvl    AllPub        ...              0      2   2006       WD
# 4            Lvl    AllPub        ...              0     12   2008       WD
# 5            Lvl    AllPub        ...            700     10   2009       WD
# 6            Lvl    AllPub        ...              0      8   2007       WD
# 7            Lvl    AllPub        ...            350     11   2009       WD
# 8            Lvl    AllPub        ...              0      4   2008       WD
# 9            Lvl    AllPub        ...              0      1   2008       WD
# 10           Lvl    AllPub        ...              0      2   2008       WD
# 11           Lvl    AllPub        ...              0      7   2006      New
# 12           Lvl    AllPub        ...              0      9   2008       WD
# 13           Lvl    AllPub        ...              0      8   2007      New
# 14           Lvl    AllPub        ...              0      5   2008       WD
# 15           Lvl    AllPub        ...              0      7   2007       WD
# 16           Lvl    AllPub        ...            700      3   2010       WD
# 17           Lvl    AllPub        ...            500     10   2006       WD
# 18           Lvl    AllPub        ...              0      6   2008       WD
# 19           Lvl    AllPub        ...              0      5   2009      COD
# 20           Lvl    AllPub        ...              0     11   2006      New
# 21           Bnk    AllPub        ...              0      6   2007       WD
# 22           Lvl    AllPub        ...              0      9   2008       WD
# 23           Lvl    AllPub        ...              0      6   2007       WD
# 24           Lvl    AllPub        ...              0      5   2010       WD
# 25           Lvl    AllPub        ...              0      7   2009       WD
# 26           Lvl    AllPub        ...              0      5   2010       WD
# 27           Lvl    AllPub        ...              0      5   2010       WD
# 28           Lvl    AllPub        ...              0     12   2006       WD
# 29           Lvl    AllPub        ...              0      5   2008       WD
# ...          ...       ...        ...            ...    ...    ...      ...
# 1430         Lvl    AllPub        ...              0      7   2006       WD
# 1431         Lvl    AllPub        ...              0     10   2009       WD
# 1432         Lvl    AllPub        ...              0      8   2007       WD
# 1433         Lvl    AllPub        ...              0      5   2008       WD
# 1434         Low    AllPub        ...              0      5   2006       WD
# 1435         Lvl    AllPub        ...              0      7   2008      COD
# 1436         Lvl    AllPub        ...              0      5   2007       WD
# 1437         Lvl    AllPub        ...              0     11   2008      New
# 1438         Lvl    AllPub        ...              0      4   2010       WD
# 1439         Lvl    AllPub        ...              0     11   2007       WD
# 1440         Bnk    AllPub        ...              0      9   2008       WD
# 1441         Lvl    AllPub        ...              0      5   2008       WD
# 1442         Lvl    AllPub        ...              0      4   2009       WD
# 1443         Lvl    AllPub        ...              0      5   2009       WD
# 1444         Lvl    AllPub        ...              0     11   2007       WD
# 1445         Lvl    AllPub        ...              0      5   2007       WD
# 1446         Lvl    AllPub        ...              0      4   2010       WD
# 1447         Lvl    AllPub        ...              0     12   2007       WD
# 1448         Lvl    AllPub        ...              0      5   2007       WD
# 1449         Lvl    AllPub        ...              0      8   2006       WD
# 1450         Lvl    AllPub        ...              0      9   2009       WD
# 1451         Lvl    AllPub        ...              0      5   2009      New
# 1452         Lvl    AllPub        ...              0      5   2006       WD
# 1453         Lvl    AllPub        ...              0      7   2006       WD
# 1454         Lvl    AllPub        ...              0     10   2009       WD
# 1455         Lvl    AllPub        ...              0      8   2007       WD
# 1456         Lvl    AllPub        ...              0      2   2010       WD
# 1457         Lvl    AllPub        ...           2500      5   2010       WD
# 1458         Lvl    AllPub        ...              0      4   2010       WD
# 1459         Lvl    AllPub        ...              0      6   2008       WD
#
#      SaleCondition SalePrice Score_MoSold  Score_GrLivArea  Score_LotArea  \
# 0           Normal    208500           30               40             71
# 1           Normal    181500           30              147             71
# 2           Normal    223500           30               40             49
# 3          Abnorml    140000           30               40             71
# 4           Normal    250000           30                3             18
# 5           Normal    143000           30              147             18
# 6           Normal    307000           30               40             71
# 7           Normal    200000           30                3             71
# 8          Abnorml    129900           30               40             71
# 9           Normal    118000           30              147             71
# 10          Normal    129500           30              147             49
# 11         Partial    345000           30                3             49
# 12          Normal    144000           30              147             18
# 13         Partial    279500           30               65             49
# 14          Normal    157000           30              147             49
# 15          Normal    132000           30              147             71
# 16          Normal    149000           30              147             49
# 17          Normal     90000           30              147             49
# 18          Normal    159000           30              147             18
# 19         Abnorml    139000           30              147             71
# 20         Partial    325300           30                3             18
# 21          Normal    139400           30              147             71
# 22          Normal    230000           30               40             71
# 23          Normal    129900           30              147            117
# 24          Normal    154000           30              147             71
# 25          Normal    256300           30               40             18
# 26          Normal    134800           30              147             71
# 27          Normal    306000           30               40             49
# 28          Normal    207500           30               40             18
# 29          Normal     68500           30              147             71
# ...            ...       ...          ...              ...            ...
# 1430        Normal    192140           30               40            -40
# 1431        Normal    143750           30              147            117
# 1432        Normal     64500           30              147             49
# 1433        Normal    186500           30               40             71
# 1434        Normal    160000           30              147            -40
# 1435       Abnorml    174000           30               65             71
# 1436        Normal    120500           30              147             71
# 1437       Partial    394617           30               40             18
# 1438        Normal    149700           30              147             71
# 1439        Normal    197000           30               40             49
# 1440        Normal    191000           30              -29             49
# 1441        Normal    149300           30              147            117
# 1442        Normal    310000           30                3             49
# 1443        Normal    121000           30              147             71
# 1444        Normal    179600           30               65             71
# 1445        Normal    129000           30              147             71
# 1446        Normal    157900           30              147            -40
# 1447        Normal    240000           30                3             71
# 1448        Normal    112000           30              147             49
# 1449       Abnorml     92000           30              147            117
# 1450        Normal    136000           30               40             71
# 1451       Partial    287090           30               40             71
# 1452        Normal    145000           30              147            117
# 1453       Abnorml     84500           30              147            -40
# 1454        Normal    185000           30              147             71
# 1455        Normal    175000           30               40             71
# 1456        Normal    210000           30                3             18
# 1457        Normal    266500           30                3             71
# 1458        Normal    142125           30              147             71
# 1459        Normal    147500           30              147             71
#
#       Score_WoodDeckSF
# 0                   41
# 1                   37
# 2                   41
# 3                   41
# 4                   41
# 5                   41
# 6                   41
# 7                   41
# 8                   41
# 9                   41
# 10                  41
# 11                  41
# 12                  41
# 13                  41
# 14                  41
# 15                  41
# 16                  41
# 17                  41
# 18                  41
# 19                  41
# 20                  41
# 21                  41
# 22                  41
# 23                  43
# 24                  35
# 25                  41
# 26                  41
# 27                  41
# 28                  37
# 29                  41
# ...                ...
# 1430                43
# 1431                41
# 1432                41
# 1433                41
# 1434                37
# 1435                41
# 1436                41
# 1437                41
# 1438                41
# 1439                41
# 1440                35
# 1441                41
# 1442                41
# 1443                41
# 1444                41
# 1445                41
# 1446                37
# 1447                41
# 1448                41
# 1449                41
# 1450                41
# 1451                41
# 1452                41
# 1453                41
# 1454                41
# 1455                41
# 1456                35
# 1457                41
# 1458                35
# 1459                35
#
# [1460 rows x 85 columns]
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# 18      19          20       RL         66.0    13695   Pave   NaN      Reg
# 19      20          20       RL         70.0     7560   Pave   NaN      Reg
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# 21      22          45       RM         57.0     7449   Pave  Grvl      Reg
# 22      23          20       RL         75.0     9742   Pave   NaN      Reg
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 24      25          20       RL          NaN     8246   Pave   NaN      IR1
# 25      26          20       RL        110.0    14230   Pave   NaN      Reg
# 26      27          20       RL         60.0     7200   Pave   NaN      Reg
# 27      28          20       RL         98.0    11478   Pave   NaN      Reg
# 28      29          20       RL         47.0    16321   Pave   NaN      IR1
# 29      30          30       RM         60.0     6324   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1430  1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1432  1433          30       RL         60.0    10800   Pave  Grvl      Reg
# 1433  1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1434  1435          20       RL         80.0    17400   Pave   NaN      Reg
# 1435  1436          20       RL         80.0     8400   Pave   NaN      Reg
# 1436  1437          20       RL         60.0     9000   Pave   NaN      Reg
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1438  1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1439  1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities     ...      MoSold YrSold SaleType SaleCondition  \
# 0            Lvl    AllPub     ...           2   2008       WD        Normal
# 1            Lvl    AllPub     ...           5   2007       WD        Normal
# 2            Lvl    AllPub     ...           9   2008       WD        Normal
# 3            Lvl    AllPub     ...           2   2006       WD       Abnorml
# 4            Lvl    AllPub     ...          12   2008       WD        Normal
# 5            Lvl    AllPub     ...          10   2009       WD        Normal
# 6            Lvl    AllPub     ...           8   2007       WD        Normal
# 7            Lvl    AllPub     ...          11   2009       WD        Normal
# 8            Lvl    AllPub     ...           4   2008       WD       Abnorml
# 9            Lvl    AllPub     ...           1   2008       WD        Normal
# 10           Lvl    AllPub     ...           2   2008       WD        Normal
# 11           Lvl    AllPub     ...           7   2006      New       Partial
# 12           Lvl    AllPub     ...           9   2008       WD        Normal
# 13           Lvl    AllPub     ...           8   2007      New       Partial
# 14           Lvl    AllPub     ...           5   2008       WD        Normal
# 15           Lvl    AllPub     ...           7   2007       WD        Normal
# 16           Lvl    AllPub     ...           3   2010       WD        Normal
# 17           Lvl    AllPub     ...          10   2006       WD        Normal
# 18           Lvl    AllPub     ...           6   2008       WD        Normal
# 19           Lvl    AllPub     ...           5   2009      COD       Abnorml
# 20           Lvl    AllPub     ...          11   2006      New       Partial
# 21           Bnk    AllPub     ...           6   2007       WD        Normal
# 22           Lvl    AllPub     ...           9   2008       WD        Normal
# 23           Lvl    AllPub     ...           6   2007       WD        Normal
# 24           Lvl    AllPub     ...           5   2010       WD        Normal
# 25           Lvl    AllPub     ...           7   2009       WD        Normal
# 26           Lvl    AllPub     ...           5   2010       WD        Normal
# 27           Lvl    AllPub     ...           5   2010       WD        Normal
# 28           Lvl    AllPub     ...          12   2006       WD        Normal
# 29           Lvl    AllPub     ...           5   2008       WD        Normal
# ...          ...       ...     ...         ...    ...      ...           ...
# 1430         Lvl    AllPub     ...           7   2006       WD        Normal
# 1431         Lvl    AllPub     ...          10   2009       WD        Normal
# 1432         Lvl    AllPub     ...           8   2007       WD        Normal
# 1433         Lvl    AllPub     ...           5   2008       WD        Normal
# 1434         Low    AllPub     ...           5   2006       WD        Normal
# 1435         Lvl    AllPub     ...           7   2008      COD       Abnorml
# 1436         Lvl    AllPub     ...           5   2007       WD        Normal
# 1437         Lvl    AllPub     ...          11   2008      New       Partial
# 1438         Lvl    AllPub     ...           4   2010       WD        Normal
# 1439         Lvl    AllPub     ...          11   2007       WD        Normal
# 1440         Bnk    AllPub     ...           9   2008       WD        Normal
# 1441         Lvl    AllPub     ...           5   2008       WD        Normal
# 1442         Lvl    AllPub     ...           4   2009       WD        Normal
# 1443         Lvl    AllPub     ...           5   2009       WD        Normal
# 1444         Lvl    AllPub     ...          11   2007       WD        Normal
# 1445         Lvl    AllPub     ...           5   2007       WD        Normal
# 1446         Lvl    AllPub     ...           4   2010       WD        Normal
# 1447         Lvl    AllPub     ...          12   2007       WD        Normal
# 1448         Lvl    AllPub     ...           5   2007       WD        Normal
# 1449         Lvl    AllPub     ...           8   2006       WD       Abnorml
# 1450         Lvl    AllPub     ...           9   2009       WD        Normal
# 1451         Lvl    AllPub     ...           5   2009      New       Partial
# 1452         Lvl    AllPub     ...           5   2006       WD        Normal
# 1453         Lvl    AllPub     ...           7   2006       WD       Abnorml
# 1454         Lvl    AllPub     ...          10   2009       WD        Normal
# 1455         Lvl    AllPub     ...           8   2007       WD        Normal
# 1456         Lvl    AllPub     ...           2   2010       WD        Normal
# 1457         Lvl    AllPub     ...           5   2010       WD        Normal
# 1458         Lvl    AllPub     ...           4   2010       WD        Normal
# 1459         Lvl    AllPub     ...           6   2008       WD        Normal
#
#      SalePrice Score_MoSold Score_GrLivArea  Score_LotArea  Score_WoodDeckSF  \
# 0       208500           30              40             71                41
# 1       181500           30             147             71                37
# 2       223500           30              40             49                41
# 3       140000           30              40             71                41
# 4       250000           30               3             18                41
# 5       143000           30             147             18                41
# 6       307000           30              40             71                41
# 7       200000           30               3             71                41
# 8       129900           30              40             71                41
# 9       118000           30             147             71                41
# 10      129500           30             147             49                41
# 11      345000           30               3             49                41
# 12      144000           30             147             18                41
# 13      279500           30              65             49                41
# 14      157000           30             147             49                41
# 15      132000           30             147             71                41
# 16      149000           30             147             49                41
# 17       90000           30             147             49                41
# 18      159000           30             147             18                41
# 19      139000           30             147             71                41
# 20      325300           30               3             18                41
# 21      139400           30             147             71                41
# 22      230000           30              40             71                41
# 23      129900           30             147            117                43
# 24      154000           30             147             71                35
# 25      256300           30              40             18                41
# 26      134800           30             147             71                41
# 27      306000           30              40             49                41
# 28      207500           30              40             18                37
# 29       68500           30             147             71                41
# ...        ...          ...             ...            ...               ...
# 1430    192140           30              40            -40                43
# 1431    143750           30             147            117                41
# 1432     64500           30             147             49                41
# 1433    186500           30              40             71                41
# 1434    160000           30             147            -40                37
# 1435    174000           30              65             71                41
# 1436    120500           30             147             71                41
# 1437    394617           30              40             18                41
# 1438    149700           30             147             71                41
# 1439    197000           30              40             49                41
# 1440    191000           30             -29             49                35
# 1441    149300           30             147            117                41
# 1442    310000           30               3             49                41
# 1443    121000           30             147             71                41
# 1444    179600           30              65             71                41
# 1445    129000           30             147             71                41
# 1446    157900           30             147            -40                37
# 1447    240000           30               3             71                41
# 1448    112000           30             147             49                41
# 1449     92000           30             147            117                41
# 1450    136000           30              40             71                41
# 1451    287090           30              40             71                41
# 1452    145000           30             147            117                41
# 1453     84500           30             147            -40                41
# 1454    185000           30             147             71                41
# 1455    175000           30              40             71                41
# 1456    210000           30               3             18                35
# 1457    266500           30               3             71                41
# 1458    142125           30             147             71                35
# 1459    147500           30             147             71                35
#
#       Score_total
# 0             182
# 1             285
# 2             160
# 3             182
# 4              92
# 5             236
# 6             182
# 7             145
# 8             182
# 9             289
# 10            267
# 11            123
# 12            236
# 13            185
# 14            267
# 15            289
# 16            267
# 17            267
# 18            236
# 19            289
# 20             92
# 21            289
# 22            182
# 23            337
# 24            283
# 25            129
# 26            289
# 27            160
# 28            125
# 29            289
# ...           ...
# 1430           73
# 1431          335
# 1432          267
# 1433          182
# 1434          174
# 1435          207
# 1436          289
# 1437          129
# 1438          289
# 1439          160
# 1440           85
# 1441          335
# 1442          123
# 1443          289
# 1444          207
# 1445          289
# 1446          174
# 1447          145
# 1448          267
# 1449          335
# 1450          182
# 1451          182
# 1452          335
# 1453          178
# 1454          289
# 1455          182
# 1456           86
# 1457          145
# 1458          283
# 1459          283
#
# [1460 rows x 86 columns]
