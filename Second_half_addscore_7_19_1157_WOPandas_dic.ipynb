# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Jul 12 03:23:51 2017

@author: Prateek Khare

Second half: if elif statement to score new dataset
"""

import sys

from IPython import get_ipython

def Scorecard_to_python2(q):
    from IPython.display import display
    from Py_elif48 import main   
    import csv
    from collections import namedtuple

    def skip_first_line(seq, n):
        for i,item in enumerate(seq):
            if i >= n:
                yield item
                
    f = open(q)
    csv_f = csv.reader(f)
    Test_line = []
    for row in skip_first_line(csv_f, 0):
    #    print(row)
        row1 = ','.join(row)
        Test_line.append(row1)  
        
    DF = list(csv.DictReader(Test_line))
    print(DF)
    
    def scoring(DF):
        if DF[MoSold]<796:
            DF[Score_MoSold]=30
        elif 796<=DF[MoSold]<1079:
            DF[Score_MoSold]=38
        elif DF[MoSold]=='NaN':
            DF[Score_MoSold]=38
        elif 1079<=DF[MoSold]<1567:
            DF[Score_MoSold]=41
        elif 1567<=DF[MoSold]<1830:
            DF[Score_MoSold]=43
        elif DF[MoSold]>=1830:
            DF[Score_MoSold]=45
        return DF
    scoring(DF)
    print(DF)
    


filename2 = ""

if len(sys.argv)==2:
    filename2 = str(sys.argv[1])
    Scorecard_to_python2(filename2)
else:
    print("1 file must be provided")

# %%
# !jupyter nbconvert --to script Second_half_addscore_7_19_1157_WOPandas_dic.ipynb
# Out:
# [NbConvertApp] Converting notebook Second_half_addscore_7_19_1157_WOPandas_dic.ipynb to script
# [NbConvertApp] Writing 1539 bytes to Second_half_addscore_7_19_1157_WOPandas_dic.py

# %%
# !python Second_half_addscore_7_19_1157_WOPandas_dic.py Test_data.csv
# Out:
# [{'PoolArea': '0', 'Foundation': 'PConc', 'EnclosedPorch': '0', 'BldgType': '1Fam', 'GarageCond': 'TA', 'PoolQC': 'NA', 'GarageQual': 'TA', 'BsmtFinSF2': '0', 'SsnPorch': '0', 'GarageArea': '548', 'BsmtFinType2': 'Unf', 'HalfBath': '1', 'ExterQual': 'Gd', 'ScreenPorch': '0', 'OverallQual': '7', 'HouseStyle': '2Story', 'RoofMatl': 'CompShg', 'LandContour': 'Lvl', 'Exterior2nd': 'VinylSd', 'LowQualFinSF': '0', 'CentralAir': 'Y', 'BsmtCond': 'TA', 'PavedDrive': 'Y', 'LotConfig': 'Inside', 'GarageType': 'Attchd', 'MiscVal': '0', 'OpenPorchSF': '61', 'BedroomAbvGr': '3', 'BsmtUnfSF': '150', 'GarageYrBlt': '2003', 'Condition2': 'Norm', 'Neighborhood': 'CollgCr', 'RoofStyle': 'Gable', 'FullBath': '2', 'Alley': 'NA', 'GarageFinish': 'RFn', 'SaleCondition': 'Normal', 'BsmtFinSF1': '706', 'Heating': 'GasA', 'TotRmsAbvGrd': '8', 'KitchenAbvGr': '1', 'Electrical': 'SBrkr', 'BsmtFullBath': '1', 'MSZoning': 'RL', 'MSSubClass': '60', 'BsmtHalfBath': '0', 'YearBuilt': '2003', 'MoSold': '2', 'ndFlrSF
# ...
